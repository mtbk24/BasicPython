# %%
from __future__ import division

# %%
try:
    raise SyntaxError('You suck')
finally:
    print('Goodbye, world!')
# Out:
# Goodbye, world!
#   File "<string>", line unknown
# SyntaxError: You suck

# %%
while True:
    try:
        x = int(raw_input("Please enter a number: "))
        print("Thank you! Your number is %i") %x
        break
    except ValueError:
        print "Oops!  That was no valid number.  Try again..."
# Out:
# Please enter a number: l
# Oops!  That was no valid number.  Try again...
# Please enter a number: s
# Oops!  That was no valid number.  Try again...
# Please enter a number: g
# Oops!  That was no valid number.  Try again...
# Please enter a number: e
# Oops!  That was no valid number.  Try again...
# Please enter a number: s
# Oops!  That was no valid number.  Try again...
# Please enter a number: 1
# Thank you! Your number is 1

# %%
while True:
    try:
        x = int(raw_input("Please enter a number: "))
        print("Thank you! Your number is %i") %x
        break
    except SyntaxError:
        print "Oops!  That was no valid number.  Try again..."
# Out:
# Please enter a number: s
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-10265028cf13> in <module>()
#       1 while True:
#       2     try:
# ----> 3         x = int(raw_input("Please enter a number: "))
#       4         print("Thank you! Your number is %i") %x
#       5         break
#
# ValueError: invalid literal for int() with base 10: 's'

# %%
import exceptions

# %%
help(__builtin__)
# Out:
# Help on built-in module __builtin__:
#
# NAME
#     __builtin__ - Built-in functions, exceptions, and other objects.
#
# FILE
#     (built-in)
#
# DESCRIPTION
#     Noteworthy: None is the `nil' object; Ellipsis represents `...' in slices.
#
# CLASSES
#     object
#         basestring
#             str
#             unicode
#         buffer
#         bytearray
#         classmethod
#         complex
#         dict
#         enumerate
#         file
#         float
#         frozenset
#         int
#             bool
#         list
#         long
#         memoryview
#         property
#         reversed
#         set
#         slice
#         staticmethod
#         super
#         tuple
#         type
#         xrange
#
#     class basestring(object)
#      |  Type basestring cannot be instantiated; it is the base for str and unicode.
#      |
#      |  Data and other attributes defined here:
#      |
#      |  __new__ = <built-in method __new__ of type object>
# ...

# %%
help(exceptions.ArithmeticError)
# Out:
# Help on class ArithmeticError in module exceptions:
#
# class ArithmeticError(StandardError)
#  |  Base class for arithmetic errors.
#  |
#  |  Method resolution order:
#  |      ArithmeticError
#  |      StandardError
#  |      Exception
#  |      BaseException
#  |      __builtin__.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(...)
#  |      x.__init__(...) initializes x; see help(type(x)) for signature
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __new__ = <built-in method __new__ of type object>
#  |      T.__new__(S, ...) -> a new object with type S, a subtype of T
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from BaseException:
#  |
#  |  __delattr__(...)
#  |      x.__delattr__('name') <==> del x.name
#  |
#  |  __getattribute__(...)
#  |      x.__getattribute__('name') <==> x.name
#  |
#  |  __getitem__(...)
# ...

# %%
Listing = (1,2,3,4,5)

# %%
Listing
# Out:
# (1, 2, 3, 4, 5)

# %%
for i in range(Listing):
    print i+1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-fa1ec3c15de6> in <module>()
# ----> 1 for i in range(Listing):
#       2     print i+1
#
# TypeError: range() integer end argument expected, got tuple.

# %%
Listing.keys()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-8552ecabecb9> in <module>()
# ----> 1 Listing.keys()
#
# AttributeError: 'tuple' object has no attribute 'keys'

# %% [markdown]
# ## AssertionError

# %%
import numpy

# %%
v = numpy.nan

# %%
assert not numpy.isnan(v) and not numpy.isinf(v), 'ERROR: parameter "v" is either NaN or inf.'
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-71-539112171ae6> in <module>()
# ----> 1 assert not numpy.isnan(v) and not numpy.isinf(v), 'ERROR: parameter "v" is either NaN or inf.'
#
# AssertionError: ERROR: parameter "v" is either NaN or inf.

# %%
numpy.love
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-84-0aa9edbba5a9> in <module>()
# ----> 1 numpy.love
#
# AttributeError: 'module' object has no attribute 'love'

# %%
a = int(raw_input("Enter a number now: "))
# Out:
# Enter a number now: r
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-87-c024cfd6e31a> in <module>()
# ----> 1 a = int(raw_input("Enter a number now: "))
#
# ValueError: invalid literal for int() with base 10: 'r'

# %%
int('r')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-88-9fecf8867b38> in <module>()
# ----> 1 int('r')
#
# ValueError: invalid literal for int() with base 10: 'r'

# %%
numpy.exp(100000000)
# Out:
# /Users/KimiZ/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: RuntimeWarning: overflow encountered in exp
#   if __name__ == '__main__':
# inf

# %%
open("kim.txt")
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-96-dd60cfb784ad> in <module>()
# ----> 1 open("kim.txt")
#
# IOError: [Errno 2] No such file or directory: 'kim.txt'

# %%
Listing
# Out:
# (1, 2, 3, 4, 5)

# %%
Listing(12)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-99-b331387d74ab> in <module>()
# ----> 1 Listing(12)
#
# TypeError: 'tuple' object is not callable

# %%
friends = {'Derek': 'husband',
          'Stef': 'sister',
          'Jess': 'cousin',
          'Janna': 'friend'
          }

# %%
friends.keys()
# Out:
# ['Stef', 'Janna', 'Derek', 'Jess']

# %%
'Kim' in friends.keys()
# Out:
# False

# %%
'Stef' in friends.keys()
# Out:
# True

# %%
'Stef' in friends
# Out:
# True

# %%
'Ste' in friends
# Out:
# False

# %%
z
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-129-a8a78d0ff555> in <module>()
# ----> 1 z
#
# NameError: name 'z' is not defined
