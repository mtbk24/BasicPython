# %% [raw]
# When grabbing data from specific columns, it is good practice to get into the habit of using either of the following to grab data:
#
#     data.loc[:, 'enaught']
#     data.loc[:, ['alpha', 'enaught']]
#     data.loc[:, 'alpha':'enaught']
#     data.loc[data.enaught > 400.0, :]
#
#
# instead of using
#
#     data['enaught']
#     data[data.enaught > 400.0].shape
#
# That way, it is also easy to remember how to grab more than one column at a time.
# For example, try out the following two on your own:
#
#     data.loc[:, ['alpha', 'enaught']]
#     data.loc[:, 'alpha':'enaught']
#
# The format goes `[rows, columns]`, so using `[:, 'enaught']` indicates all rows in the 'enaught' column. `[:, ['alpha', 'enaught']]` meas all rows in the 'alpha' and 'enaught' columns. `[:, 'alpha':'enaught']` means all rows in the 'alpha' through 'enaught' columns (all columns inbetween).
#
#
# Another good habit to get into, and one that is **critical**, is the practice of using either of the following two:
#
#     data.loc[:, 'norm'] = 10**(data.loc[:, 'norm'])
#     data.norm.update(10**data.norm)       # aligns on index.
#
# instead of using
#
#     data['norm'] = 10**(data.norm)
#
# The latter example is the one I have used for many years in my research, and it has caused me many many painful hours to days to fix the issues it has caused.
#
# __Here is why:__
#
# In certain circumstances, a Warning will be thrown by pandas, which is often ignored by many users (including myself) and it SHOULD NOT BE.
# The warning looks something like this:
# ```
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# ```
# __What does this mean?__
# Pandas is warning you that they don't know whether you are assigning these new values to a view or a copy of the dataframe. This has to do with something called `chained indexing`, which is explained [here:](http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#indexing-view-versus-copy).
# If chained indexing is ued to assign to a dataframe, the changes can not stick and you can be left with the original values.
#
# __Other Resources on this topic:__
# - Documentation on indexing and selection: [Returning a view versus a copy](http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy)
# - Stack Overflow: [What is the point of views in pandas if it is undefined whether an indexing operation returns a view or a copy?](http://stackoverflow.com/questions/34884536/what-is-the-point-of-views-in-pandas-if-it-is-undefined-whether-an-indexing-oper)

# %%
from __future__ import division # using Python 2.7
import numpy as np
import pandas as pd 
import matplotlib
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Read In Data

# %%
f='/Users/KimiZ/GRBs2/analysis/LAT/bn080916009/BXA/GBMwLAT/grbm/grbm_-01-_L_.txt'

# %%
# Read a table of fixed-width formatted lines into DataFrame
data = pd.read_fwf(f, names=range(0,6))
data.head()
# Out:
#               0           1         2         3            4         5
# 0  1.464804e-99  774.965035 -1.094847 -2.334929   607.719256 -1.724910
# 1  1.551436e-99  774.847617 -1.251852 -2.282142  1739.260013 -1.814916
# 2  1.600356e-99  774.783027 -1.222781 -2.692320  2722.137812 -1.883588
# 3  1.622601e-99  774.752918 -1.328367 -2.237835  1735.107763 -1.885350
# 4  1.778115e-99  774.567371 -1.174649 -2.390003   880.591390 -1.775047

# %% [markdown]
# **Using Numpy's `loadtxt`**

# %% [raw]
# # Another way to do this is read it in with numpy's loadtxt
# # then put into a pandas dataframe
# # numpy read text file in data format.
#
# data_ = np.loadtxt(f)
# print(data_.shape)
#
# # READ INTO PANDAS DATAFRAME
# data_ = pd.DataFrame(data_)

# %% [markdown]
# They are the same!

# %%
data.head()
# Out:
#               0           1         2         3            4         5
# 0  1.464804e-99  774.965035 -1.094847 -2.334929   607.719256 -1.724910
# 1  1.551436e-99  774.847617 -1.251852 -2.282142  1739.260013 -1.814916
# 2  1.600356e-99  774.783027 -1.222781 -2.692320  2722.137812 -1.883588
# 3  1.622601e-99  774.752918 -1.328367 -2.237835  1735.107763 -1.885350
# 4  1.778115e-99  774.567371 -1.174649 -2.390003   880.591390 -1.775047

# %% [markdown]
# ```
#
# ```
# ## Band Function
#
#
# The modeling function used in this example to fit the GRB's data is known as the [Band Function](http://adsabs.harvard.edu/abs/1993ApJ...413..281B), which has become the *standard grb model*. Since we used the XSPEC function for the Importance Nested Sampling procedure, we refer you to the [XSPEC grbm function](https://heasarc.gsfc.nasa.gov/xanadu/xspec/manual/node179.html) for the function's equaton and parameter explanations.
#
# The characteristic energy ($E_c$), or rater $E_0$ if you check out the notation used by the authors who developed this function ([Band et al. 19993](http://adsabs.harvard.edu/abs/1993ApJ...413..281B)), is related to the more familiar $\nu F_{\nu}$ peak energy ($E_{pk}$) through the following equation:
#
# \begin{equation}
# E_0 = \frac{E_{pk}}{(\alpha + 2)} .
# \end{equation}
#
# Since many GRB correlations utilize the $E_{pk}$, we will convert all energies to it and name this parameter "epeak".
#
# In addition, the normalization ('norm') parameter is logged, so we will un-log those values.
#
# ```
#
# ```
#
#
# ### Data Table Columns:
#     ['prob', 'cstat', 'alpha', 'beta', 'epeak', 'norm']
#
#
# * 'prob' stands for probability.
# * $\text{cstat} = -2*\text{log_likelihood}$  from the Importance Nested Sampling procedure.
# * 'alpha', 'beta', 'epeak', 'norm' are the spectral modeling parameters of the Band function.

# %% [markdown]
# ## Rename Column Headers

# %%
data.columns = ['prob', 'cstat', 'alpha', 'beta', 'enaught', 'norm']

# %%
data.head()
# Out:
#            prob       cstat     alpha      beta      enaught      norm
# 0  1.464804e-99  774.965035 -1.094847 -2.334929   607.719256 -1.724910
# 1  1.551436e-99  774.847617 -1.251852 -2.282142  1739.260013 -1.814916
# 2  1.600356e-99  774.783027 -1.222781 -2.692320  2722.137812 -1.883588
# 3  1.622601e-99  774.752918 -1.328367 -2.237835  1735.107763 -1.885350
# 4  1.778115e-99  774.567371 -1.174649 -2.390003   880.591390 -1.775047

# %% [markdown]
# ### Showing how to compute 1-sigma quantiles

# %%
# 1-sigma quantiles:  [lower, middle, upper] or numerically [15.865, 50, 84.135]
quants = [50.-(68.27/2.), 50., 50.+(68.27/2.)]

# alpha 1-sigma quantiles
alpha_quants = np.percentile(data.alpha, q=quants)
print(alpha_quants)

# enaught 1-sigma quantiles
enaught_quants = np.percentile(data.enaught, q=quants)
print(enaught_quants)

# epeak 1-sigma quantiles
epeak_quants = np.percentile(data.enaught*(data.alpha + 2.), q=quants)
print(epeak_quants)

print('')
print( enaught_quants*(alpha_quants+2.) )
# Out:
# [-1.1425639  -1.04421066 -1.0017253 ]
# [  473.03248438   567.74058107  1025.19775694]
# [ 469.56555001  542.3029819   877.38114221]
#
# [  405.59512686   542.64039772  1023.42898654]

# %% [markdown]
# __It is NOT the same to take the quantiles of the individual parameters and THEN compute epeak's quantiles from those. Each epeak depends on its enaught and alpha, so all epeaks must be calculated first and then we can find the quantiles of the epeak distribution.__

# %% [markdown]
# ### Lets update the dataframe now

# %%
# replace 'enaught' with epeak values
data.loc[:, 'enaught'] = data.enaught*(data.alpha + 2.0)  # epeak = E0*(alpha+2.0)

# rename the column to 'epeak'
data.columns = data.columns.str.replace('enaught', 'epeak')
data.head()
# Out:
#            prob       cstat     alpha      beta        epeak      norm
# 0  1.464804e-99  774.965035 -1.094847 -2.334929   550.078935 -1.724910
# 1  1.551436e-99  774.847617 -1.251852 -2.282142  1301.223931 -1.814916
# 2  1.600356e-99  774.783027 -1.222781 -2.692320  2115.696039 -1.883588
# 3  1.622601e-99  774.752918 -1.328367 -2.237835  1165.356094 -1.885350
# 4  1.778115e-99  774.567371 -1.174649 -2.390003   726.796834 -1.775047

# %% [raw]
# # unlog the normalizations
# data.loc[:, 'norm'] = 10**(data.loc[:, 'norm'])
#
# data.head()

# %% [markdown]
# ## Sort Data by Cstat
# The dataframe is already sorted by Cstat, but in descending order. However, we wish to sort it by ascending order. In `data.sort_values`, there is a parameter called `ascending` and its defalut is `True`. So we do not need to use it.
#
# data.cstat.plot()
#
# data.sort_values(by='cstat', inplace=True)
#
# data.head()
#
# data.tail()
#
# data.cstat.plot()

# %% [markdown]
# # Plots

# %%
data.hist(bins=100, figsize=(11,9))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11fe43910>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f950b90>]], dtype=object)

# %%
# ?plt.hexbin

# %%
data.plot.hexbin('alpha','beta', bins='log', 
                 gridsize=25, cmap=plt.cm.Blues)

# %%
plt.hexbin(data.alpha, 
           data.beta, 
           bins='log', 
           gridsize=25, 
           cmap=plt.cm.Blues)

# %%
data.alpha.plot.kde?

# %%
plt.rcParams
# Out:
# RcParams({u'_internal.classic_mode': False,
#           u'agg.path.chunksize': 0,
#           u'animation.avconv_args': [],
#           u'animation.avconv_path': u'avconv',
#           u'animation.bitrate': -1,
#           u'animation.codec': u'h264',
#           u'animation.convert_args': [],
#           u'animation.convert_path': u'convert',
#           u'animation.embed_limit': 20.0,
#           u'animation.ffmpeg_args': [],
#           u'animation.ffmpeg_path': u'ffmpeg',
#           u'animation.frame_format': u'png',
#           u'animation.html': u'none',
#           u'animation.html_args': [],
#           u'animation.mencoder_args': [],
#           u'animation.mencoder_path': u'mencoder',
#           u'animation.writer': u'ffmpeg',
#           u'axes.autolimit_mode': u'data',
#           u'axes.axisbelow': u'line',
#           u'axes.edgecolor': u'k',
#           u'axes.facecolor': u'w',
#           u'axes.formatter.limits': [-7, 7],
# ...

# %%
plt.clf()
for col in data.columns:
    eval('data.%s.plot.kde()'%col)
    plt.show()

# %%
data.beta.plot.kde()

# %%
data.plot.density()

# %%
data.plot(kind='scatter', x='alpha', y='cstat', marker='.')

# %%
data.loc[data.cstat<500, :].plot(kind='scatter', 
                                 x='alpha', y='cstat', 
                                 marker='.')

# %%
# data.cstat.mean() is 395
data.loc[data.cstat<data.cstat.mean(), :].plot(kind='scatter', 
                                 x='alpha', y='cstat', 
                                 marker='.', alpha=0.25)

# %%
data.plot(kind='scatter', x='alpha', y='cstat', 
          marker='.', 
          lw=0,    # not specifically a scatter, so need lw = 0
          xlim=(-1.4, -0.5))

# %%
# in matplotlib

xvar = 'alpha'
yvar = 'cstat'

x = eval('data.%s'%xvar)
y = eval('data.%s'%yvar)
plt.scatter(x, y, marker='.', alpha=0.25)
plt.xlabel(xvar)
plt.ylabel(yvar)
# Out:
# Text(0,0.5,u'cstat')

# %%
# in matplotlib

xvar = 'alpha'
yvar = 'cstat'

# row and column conditionals
# if all rows or cols desired, simply use ':'
# must be passed as strings.
row_cond = 'data.cstat>300' # cstats above 300
col_cond = ':'              # all columns

x = eval('data.loc[%s, %s].%s'%(row_cond, col_cond, xvar))
y = eval('data.loc[%s, %s].%s'%(row_cond, col_cond, yvar))
plt.scatter(x, y, marker='.', alpha=0.25)
plt.xlabel(xvar)
plt.ylabel(yvar)
# Out:
# Text(0,0.5,u'cstat')

# %%
# in matplotlib

xvar = 'alpha'
yvar = 'cstat'

# row and column conditionals
# if all rows or cols desired, simply use ':'
# must be passed as strings.
row_cond = 'data.cstat<320' # cstats < 320
col_cond = ':'              # all columns

x = eval('data.loc[%s, %s].%s'%(row_cond, col_cond, xvar))
y = eval('data.loc[%s, %s].%s'%(row_cond, col_cond, yvar))
plt.scatter(x, y, marker='.', alpha=0.25)
plt.xlabel(xvar)
plt.ylabel(yvar)
# Out:
# Text(0,0.5,u'cstat')

# %%
x.shape # 3380 have cstats < 320.
# Out:
# (3380,)

# %%
len(x)/len(data) # 33%
# Out:
# 0.3282828282828283

# %%
# in matplotlib

xvar = 'beta'
yvar = 'cstat'

# row and column conditionals
# if all rows or cols desired, simply use ':'
# must be passed as strings.
row_cond = 'data.cstat<320' # cstats < 320
col_cond = ':'              # all columns

x = eval('data.loc[%s, %s].%s'%(row_cond, col_cond, xvar))
y = eval('data.loc[%s, %s].%s'%(row_cond, col_cond, yvar))
plt.scatter(x, y, marker='.', alpha=0.25)
plt.xlabel(xvar)
plt.ylabel(yvar)
# Out:
# Text(0,0.5,u'cstat')

# %%
data.loc[:, 'norm'] = np.log10(data.loc[:, 'norm'])

# %%
# in matplotlib

plt.clf()
for col in data.columns[2:]:
    xvar = col
    yvar = 'cstat'

    # row and column conditionals
    # if all rows or cols desired, simply use ':'
    # must be passed as strings.
    row_cond = 'data.cstat<320' # cstats < 320
    col_cond = ':'              # all columns

    x = eval('data.loc[%s, %s].%s'%(row_cond, col_cond, xvar))
    y = eval('data.loc[%s, %s].%s'%(row_cond, col_cond, yvar))
    plt.scatter(x, y, marker='.', alpha=0.25)
    plt.xlabel(xvar)
    plt.ylabel(yvar)
    plt.show()

# %%
x = np.arange(1, len(data.cstat)+1, 1)
y = data.cstat
plt.scatter(x,y)

# %%
x = np.arange(1, len(data.cstat)+1, 1)
y = data.cstat
plt.scatter(x,y)

# %%
data.cstat.plot()

# %%
data.plot(kind='scatter')
# Out:
# ------------------------------------------------------------------------
# ValueError                             Traceback (most recent call last)
# <ipython-input-27-34e997cddd0f> in <module>()
# ----> 1 data.plot(kind='scatter')
#
# /Users/KimiZ/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    3772                           fontsize=fontsize, colormap=colormap, table=table,
#    3773                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 3774                           sort_columns=sort_columns, **kwds)
#    3775     __call__.__doc__ = plot_frame.__doc__
#    3776
#
# ...

# %%
data.prob.plot()

# %%
data.prob.cumsum().plot()

# %%
data.shape
# Out:
# (10296, 6)

# %%
data.hist(bins=100, figsize=(11,9))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1142dd210>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114666890>]], dtype=object)

# %%
data.hist(bins=100, figsize=(11,9), normed=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x114790fd0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11658a0d0>]], dtype=object)

# %% [markdown]
# ### Grab the first 3000 rows of data (with the lowest Cstats)
# The method we use is called slicing.

# %%
data.loc[:3000, :].cstat.plot()

# %%
data2 = data[:3000] # slicing

# %%
data.shape

# %%
data2.shape

# %%
data2.columns

# %% [markdown]
# __Original plot of data, alpha parameter vs beta parameter. This includes all 13405 of the nested sampling results.__

# %%
xvar = 'alpha'
yvar = 'beta'

x = eval('data.%s'%xvar)
y = eval('data.%s'%yvar)

plt.plot(x, y, 'x')
plt.xlabel(xvar)
plt.ylabel(yvar)
plt.show()

# %% [markdown]
# __Plot of 3000 best CStats values from nesting sampling results. alpha parameter vs beta parameter.__

# %%
xvar = 'alpha'
yvar = 'beta'

x = eval('data2.%s'%xvar)
y = eval('data2.%s'%yvar)

plt.plot(x, y, 'x')
plt.xlabel(xvar)
plt.ylabel(yvar)
plt.show()

# %% [markdown]
# __Same plot in pandas:__

# %%
xvar = 'alpha'
yvar = 'beta'
data2.plot(xvar, yvar, kind='scatter', marker='x', s=40, lw=0.75)

# %%
# ?plt.scatter

# %%
data2.hist(figsize=(10,6))

# %%
import pandas.plotting.scatter_matrix as sc_mat

# %%
x = data3[4] # beta
y = data3[2] # alpha

plt.plot(x, y, 'x')
plt.xlabel('ebreak')
plt.ylabel('alpha')
plt.show()

# %%
data4 = data3

# %%
data4.columns = 'prob cstat alpha beta ebreak norm_b plidx norm_p'.split()

# %%
data4.columns

# %%
data4[:5]

# %%
data3[:5]

# %% [markdown]
# ### You should notice that data3 column names also changed because data4 is a copy of it.
# Now we will check to see if the origianl dataframe, data1, changed as well.

# %%
data1[:2], data2[:2]

# %% [markdown]
# Neither of these changed, so it is only the last assignment that changes.

# %%
data3.plot.hexbin(x='ebreak', y='alpha', gridsize=50)

# %%
data3.plot.hexbin(x='beta', y='alpha', gridsize=50)

# %% [markdown]
# 'A useful keyword argument is gridsize; it controls the number of hexagons in the x-direction, and defaults to 100. A larger gridsize means more, smaller bins.
#
# By default, a histogram of the counts around each (x, y) point is computed. You can specify alternative aggregations by passing values to the C and reduce_C_function arguments. C specifies the value at each (x, y) point and reduce_C_function is a function of one argument that reduces all the values in a bin to a single number (e.g. mean, max, sum, std). In this example the positions are given by columns a and b, while the value is given by column z. The bins are aggregated with numpy’s max function.'
#
# http://pandas.pydata.org/pandas-docs/stable/visualization.html

# %%
data2.plot.hexbin(x='beta', y='alpha', C='cstat', gridsize=50)# reduce_C_function=np.mean, gridsize=50)

# %%
help(data2.plot.hexbin)

# %%
data2.plot.hexbin(x='beta', y='alpha', C='cstat', gridsize=50)# reduce_C_function=np.mean, gridsize=50)

# %% [markdown]
# In the above example, my cstat values and colors are reversed from what I want them to be.  Ther darker values favors maximum numbers.  So I decided to use those numbers to solve for the log-likelihood values.  cstat = -2*loglikelihood.  So I made a column in the dataframe called loglike and gave it the values of cstat/-2.  This way the larger numbers, still darker in color, are now the most favorable values instead of the least favorable.

# %%
data2['loglike'] = data2['cstat']/-2.

# %%
data2.plot.hexbin(x='beta', y='alpha', C='loglike', gridsize=50)# reduce_C_function=np.mean, gridsize=50)

# %% [markdown]
# The maximum likelihood values are those with the lowest cstat values, on line 6193 of the original datafile and now the first line of our dataset.  Going back to the dataset that is sorted by cstat but not truncated is data2.

# %%
data2['loglike'][6181] # apparently this one uses the index value instead of row number, which is confusing.

# %% [markdown]
# What is the point (beta, alpha) at the maximum likelihood value?
#
# data2['loglike'][6192]

# %%
x_p = data2['beta'][6192]
y_p = data2['alpha'][6192]

# %%
(x_p, y_p)

# %%
help(plt.plot)

# %% [markdown]
# Since panda's plotting package is built off of matplotlib, matplotlib plotting commands will plot over pandas.
#
# Panda's plotting package is called Visualization.  http://pandas.pydata.org/pandas-docs/stable/visualization.html
# It's style is 'ggplot', which is the name of the widely used plotting package in R.

# %%
data2.plot.hexbin(x='beta', y='alpha', C='loglike', gridsize=50)# reduce_C_function=np.mean, gridsize=50)
plt.plot(x_p, y_p, '+', color='white', markeredgewidth = 2, markersize=12)
